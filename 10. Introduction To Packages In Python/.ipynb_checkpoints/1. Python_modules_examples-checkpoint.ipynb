# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Python-Notebook-Banners/Examples.png"  style="display: block; margin-left: auto; margin-right: auto;";/>
# </div>

# %% [markdown]
# # Examples: Python modules

# %% [markdown]
# This notebook accompanies the walk-through video on Python modules and packages and also contains a few additional examples on how we can use modules.

# %% [markdown]
# ## Learning objectives
# In this train, we will learn how to:
# - Write a module and import all or specific objects from a module.
# - Import modules using an alias name and explore the use of built-in modules.
#
#
# ## Outline
# To do this, we will:
# - Define the importance of modules and packages in programming.
# - Review the syntax and conventions for importing modules.
# - Consider the use of built-in Python modules.

# %% [markdown]
# ## Introduction
# Modular programming is a style of programming that promotes code reusability, allowing us to generate single pieces of code which can be used in multiple parts of a project – thus saving time and resources. The resulting code can be simpler to understand and maintain since components can be considered in isolation. In Python, **modularisation** is implemented using functions, modules, and packages.
#
# A **module** is a file consisting of Python code. A module can define functions, classes, variables, and runnable code. These modules can be imported and referenced from other Python code. A **Python package** (also referred to as a library) is a collection of hierarchically structured directories of Python code consisting of sub-packages and modules.
#
# Modules and packages are two mechanisms that facilitate modular programming.
#
# ## Why modularisation?
#
# * **Reusability**: Eliminates the need to write new code, as functionality defined in a single module can be easily reused.
#
#
# * **Simplicity**: Modules generally tend to focus on a selected area of the problem which is usually small, rather than focusing on the entire problem at hand. Integrating the use of selected modules will result in systematically dealing with each small problem in the code, making development easier and less error-prone.
#
#
# * **Maintainability**: Modules in Python are often designed to be self-supporting. In this sense, one module does not depend entirely upon other modules to work. Therefore, it is unlikely that modifying a single module of a program will affect other parts of the program. This allows a team of many programmers or data scientists to work collaboratively on a large application.

# %% [markdown]
# ## Working with modules
#
# ### Creating modules
# Creating a module is as simple as saving a Python script with functions, classes, variables and running code. The file name is the module name with the suffix `.py` appended.
#
# ### Importing modules
# We can access this module and its elements from a different Python file by using the `import` statement.
# * We can import a single module/package:
#
#     ```python
#     import <module_name>
#     ```
#
# * Import multiple modules using individual import statements:
#
#     ```python
#     import <module_1_name>
#     import <module_2_name>
#     import <module_3_name>
#     ...```
#
#
#
# The same rules apply when dealing with packages. We can import specific modules within a package by using dot notation. For this to work, we have to structure packages and modules in a way that reflects the hierarchy in the package directory.
#
#    ```python
#     import <package_name>.<sub_package_name>.<module_name>.<...>
#    ```
#
# Let's go ahead and create our own module, with the following three types of elements:
#
# *   A variable `s`
# *   A function `say_hi()`
# *   A class `Greet`

# %%
# Contents of the module we are creating 
content = """
s = 'Hello ' 

def say_hi(name):
    print(s + name)

class Greet:
    pass
"""

# Write the above text to a file called my_module.py
# within our current working directory. 
with open('./my_module.py', 'w') as fp:
    fp.write(content)

# %% [markdown]
# This command writes (or saves) our module into our working directory so that we can use it again.

# %%
#Import the module we've just made! 
import my_module

# %% [markdown]
# Even though we've imported our module, note that its contents (the variables and functions we've defined within the module) are not directly accessible to us. As such, attempting to access these elements will result in (namespace) errors being thrown. We can safely see such errors using a `try-except` block:

# %%
try:
    # Try to print the variable s
    print(s)
except NameError:
    # We've caught a NameError exception (error!)
    # We inform the programmer (you) that the variable does not exist
    print("Variable 's' does not exist!")
# Out:
# Variable 's' does not exist!

# %% [markdown]
# Learning from this experience, it is important to know that objects in a module are only accessible when prefixed with via dot notation, as illustrated below.

# %%
# Accessing the variable s in my_module
my_module.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function in my_module
my_module.say_hi('Nelson')
# Out:
# Hello Nelson

# %% [markdown]
# ### Example: Importing modules using an alias
# The `import` statement in Python also allows for the use of aliases when referencing a module. Using the `as` keyword, we can save ourselves from having to type otherwise long package names each time we need to access an object from a given module/package. This usually follows the following syntax:
#
# ```python
# import <module_name> as <new_model_name>
# ```
# or
#
# ```python
# from <package_name> import <module_name> as <new_model_name>
# ```
#
# For example:

# %%
# Alias for my_module
import my_module as md

# %% [markdown]
# We can thus treat the alias as the new name for the module.

# %%
# Accessing the variable s using an alias
md.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function using an alias for my_module
md.say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
# Accessing the empty class, Greet
md.Greet
# Out:
# my_module.Greet

# %% [markdown]
# ### Example: Importing modules directly
# Another way to access specific objects in a module is to use the `from` keyword and import them directly:
#
# ```python
# from <module_name> import <x, y, z>
# ```

# %%
from my_module import s, say_hi, Greet

# %%
s
# Out:
# 'Hello '

# %%
say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# We can see that using the `from xx import yy` structure provides access to the individual elements in the module without having to use dot notation. However, using aliases is the recommended way of importing modules and packages, as this prevents potential confusion when different modules contain functions or classes with the same name.
#
# To select all objects from a module we can use the following command, where the asterisk **( * )** *signifies all* :
#
# ```python
# from <module_name> import*
# ```
# Let's see this in practice one more time:

# %%
from my_module import *

# %% [markdown]
# Now we have access to all our module contents.

# %%
say_hi('Joanne')
# Out:
# Hello Joanne

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# ## Built-in modules
# Python contains a large number of what are known as 'built-in' modules. These modules can be accessed in Python programs by simply importing them using their name preceded by the keyword `import`.
#
# Each built-in module contains resources for certain system-specific functionalities such as operating system management, disk input-output, etc. Python scripts (with the **.py** extension) containing useful utilities are embedded within the standard library.
#
# To **display a list of all available modules**, use the following command:
#
# `help('modules')`

# %%
help('modules') # this might take a while
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\gmutisya\AppData\Local\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\Users\gmutisya\AppData\Local\anaconda3\Lib\site-packages\pydantic\experimental\__init__.py:7: PydanticExperimentalWarning:
#
# This module is experimental, its contents are subject to change and deprecation.
#
# C:\Users\gmutisya\AppData\Local\anaconda3\Lib\pkgutil.py:78: UserWarning:
#
# The superqt.qtcompat module is deprecated as of v0.3.0. Please import from `qtpy` instead.
# 3204bda914b7f2c6f497__mypyc cloudpickle         matplotlib          six
# IPython             cmath               matplotlib_inline   skimage
# OpenSSL             cmd                 mccabe              sklearn
# PIL                 code                mdit_py_plugins     sklearn_compat
# PyQt5               codecs              mdurl               slugify
# PySide6             codeop              menuinst            smmap
# __future__          collections         mimetypes           smtplib
# __hello__           colorama            mistune             sniffio
# __phello__          colorcet            mkl                 snowballstemmer
# _abc                colorsys            mkl_fft             socket
# _aix_support        comm                mkl_random          socketserver
# _android_support    commctrl            mmap                socks
# _apple_support      compileall          mmapfile            sockshandler
# _argon2_cffi_bindings concurrent          mmsystem            sortedcontainers
# _ast                conda               modulefinder        soupsieve
# _asyncio            conda_anaconda_telemetry more_itertools      sphinx
# _bisect             conda_anaconda_tos  mpmath              spyder
# _black_version      conda_build         msgpack             spyder_kernels
# _blake2             conda_content_trust msvcrt              sqlalchemy
# _brotli             conda_env           multidict           sqlite3
# _bz2                conda_index         multipledispatch    sre_compile
# _cffi_backend       conda_libmamba_solver multiprocessing     sre_constants
# _codecs             conda_pack          my_module           sre_parse
# _codecs_cn          conda_package_handling mypy                ssl
# _codecs_hk          conda_package_streaming mypy_extensions     sspi
# _codecs_iso2022     configparser        mypyc               sspicon
# _codecs_jp          constantly          nacl                stack_data
# _codecs_kr          contextlib          narwhals            start_pythonwin
# _codecs_tw          contextvars         navigator_updater   stat
# _collections        contourpy           nbclient            statistics
# _collections_abc    cookiecutter        nbconvert           statsmodels
# _colorize           copy                nbformat            streamlit
# _compat_pickle      copyreg             nest_asyncio        string
# _compression        cpuinfo             netbios             stringprep
# _contextvars        cryptography        netrc               struct
# _csv                cssselect           networkx            subprocess
# _ctypes             csv                 nltk                superqt
# _ctypes_test        ctypes              notebook            sympy
# _datetime           curl                notebook_shim       symtable
# _decimal            curses              nt                  sys
# _distutils_hack     cwp                 ntpath              sysconfig
# _elementtree        cycler              ntsecuritycon       tables
# _functools          cytoolz             nturl2path          tabnanny
# _hashlib            dask                numba               tabulate
# _heapq              dask_expr           numbergen           tarfile
# _imp                dataclasses         numbers             tblib
# _interpchannels     datashader          numexpr             tempfile
# _interpqueues       datetime            numpy               tenacity
# _interpreters       dateutil            numpydoc            terminado
# _io                 dbm                 odbc                test
# _ios_support        dde                 opcode              test_pycosat
# _json               debugpy             openpyxl            text_unidecode
# _locale             decimal             operator            textdistance
# _lsprof             decorator           optparse            textwrap
# _lzma               defusedxml          ordered_set         this
# _markupbase         deprecated          os                  threading
# _md5                diff_match_patch    overrides           threadpoolctl
# _multibytecodec     difflib             packaging           three_merge
# _multiprocessing    dill                pandas              tifffile
# _nsis               dis                 pandocfilters       time
# _opcode             distributed         panel               timeit
# _opcode_metadata    distro              param               timer
# _operator           docstring_to_markdown parsel              tinycss2
# _osx_support        doctest             parso               tkinter
# _overlapped         docutils            partd               tldextract
# _pickle             dotenv              pathlib             tlz
# _plotly_future_     email               pathspec            token
# _plotly_utils       encodings           patsy               tokenize
# _py_abc             ensurepip           pdb                 toml
# _pydatetime         enum                perfmon             tomli
# _pydecimal          erfa                pexpect             tomlkit
# _pyio               errno               pickle              tomllib
# _pylong             et_xmlfile          pickleshare         toolz
# _pyrepl             evalidate           pickletools         tornado
# _pytest             executing           pip                 tqdm
# _queue              fastjsonschema      pkce                trace
# _random             faulthandler        pkg_resources       traceback
# _ruamel_yaml        filecmp             pkginfo             tracemalloc
# _sha1               fileinput           pkgutil             traitlets
# _sha2               filelock            platform            truststore
# _sha3               flake8              platformdirs        tty
# _signal             flask               plistlib            turtle
# _sitebuiltins       fnmatch             plotly              turtledemo
# _socket             fontTools           pluggy              twisted
# _sqlite3            fractions           ply                 typeguard
# _sre                frozendict          poplib              typer
# _ssl                frozenlist          posixpath           types
# _stat               fsspec              poyo                typing
# _statistics         ftplib              pprint              typing_extensions
# _string             functools           profile             tzdata
# _strptime           gc                  prometheus_client   uc_micro
# _struct             genericpath         prompt_toolkit      ujson
# _suggestions        getopt              propcache           unicodedata
# _symtable           getpass             protego             unidecode
# _sysconfig          gettext             pstats              unittest
# _system_path        git                 psutil              urllib
# _testbuffer         gitdb               pty                 urllib3
# _testcapi           github              ptyprocess          uuid
# _testclinic         glob                pure_eval           venv
# _testclinic_limited gmpy2               py                  w3lib
# _testconsole        graphlib            py_compile          warnings
# _testimportmultiple greenlet            pyarrow             watchdog
# _testinternalcapi   gzip                pyasn1              wave
# _testlimitedcapi    h11                 pyasn1_modules      wcwidth
# _testmultiphase     h5py                pyclbr              weakref
# _testsinglephase    hashlib             pycodestyle         webbrowser
# _thread             heapdict            pycosat             webencodings
# _threading_local    heapq               pycparser           websocket
# _tkinter            hmac                pyct                werkzeug
# _tokenize           holoviews           pycurl              whatthepatch
# _tracemalloc        html                pydantic            wheel
# _typing             http                pydantic_core       widgetsnbextension
# _uuid               httpcore            pydantic_settings   win2kras
# _warnings           httpx               pydispatch          win32api
# _weakref            hvplot              pydoc               win32clipboard
# _weakrefset         hyperlink           pydoc_data          win32com
# _win32sysloader     idlelib             pydocstyle          win32con
# _win32verstamp_pywin32ctypes idna                pyexpat             win32console
# _winapi             imageio             pyflakes            win32cred
# _winxptheme         imagesize           pygments            win32crypt
# _wmi                imaplib             pylab               win32cryptcon
# _yaml               imblearn            pylint              win32ctypes
# _zoneinfo           importlib           pylint_venv         win32event
# abc                 importlib_metadata  pyls_spyder         win32evtlog
# adodbapi            importlib_resources pylsp               win32evtlogutil
# afxres              incremental         pylsp_black         win32file
# aiobotocore         inflect             pylsp_jsonrpc       win32gui
# aiohappyeyeballs    inflection          pyodbc              win32gui_struct
# aiohttp             iniconfig           pyparsing           win32help
# aioitertools        inspect             pytest              win32inet
# aiosignal           intake              pythoncom           win32inetcon
# alabaster           intervaltree        pythonjsonlogger    win32job
# altair              io                  pytoolconfig        win32lz
# anaconda_anon_usage ipaddress           pytz                win32net
# anaconda_auth       ipykernel           pyuca               win32netcon
# anaconda_catalogs   ipykernel_launcher  pyviz_comms         win32pdh
# anaconda_cli_base   ipywidgets          pywin               win32pdhquery
# anaconda_cloud_auth isapi               pywin32_bootstrap   win32pdhutil
# anaconda_navigator  isort               pywin32_testutil    win32pipe
# anaconda_project    isympy              pywintypes          win32print
# annotated_types     itemadapter         pywt                win32process
# antigravity         itemloaders         qdarkstyle          win32profile
# anyio               itertools           qstylizer           win32ras
# appdirs             itsdangerous        qtawesome           win32rcparser
# archspec            jedi                qtconsole           win32security
# argon2              jellyfish           qtpy                win32service
# argparse            jinja2              queue               win32serviceutil
# array               jinja2_time         queuelib            win32timezone
# arrow               jmespath            quopri              win32trace
# ast                 joblib              random              win32traceutil
# astroid             json                rasutil             win32transaction
# astropy             json5               re                  win32ts
# astropy_iers_data   jsonpatch           readchar            win32ui
# asttokens           jsonpointer         referencing         win32uiole
# async_lru           jsonschema          regcheck            win32verstamp
# asyncio             jsonschema_specifications regex               win32wnet
# asyncssh            jupyter             regutil             win_inet_pton
# atexit              jupyter_client      repo_cli            winerror
# atomicwrites        jupyter_console     reprlib             winioctlcon
# attr                jupyter_core        requests            winnt
# attrs               jupyter_events      requests_file       winperf
# autocommand         jupyter_lsp         requests_toolbelt   winpty
# automat             jupyter_server      rfc3339_validator   winreg
# autopep8            jupyter_server_terminals rfc3986_validator   winsound
# babel               jupyterlab          rich                winxpgui
# backports           jupyterlab_plotly   rlcompleter         winxptheme
# base64              jupyterlab_pygments roman_numerals      wrapt
# bcrypt              jupyterlab_server   rope                wsgiref
# bdb                 jupyterlab_widgets  rpds                xarray
# binaryornot         jwt                 rtree               xlwings
# binascii            keyring             ruamel_yaml         xlwingsjs
# binstar_client      keyword             runpy               xml
# bisect              kiwisolver          s3fs                xmlrpc
# black               lazy_loader         sched               xxlimited
# blackd              lckr_jupyterlab_variableinspector scipy               xxlimited_35
# bleach              libarchive          scrapy              xxsubtype
# blib2to3            libmambapy          seaborn             xyzservices
# blinker             lief                secrets             yaml
# bokeh               linecache           select              yapf
# boltons             linkify_it          selectors           yapf_third_party
# botocore            llvmlite            semver              yapftests
# bottleneck          lmdb                send2trash          yarl
# brotli              locale              service_identity    zict
# bs4                 locket              servicemanager      zipapp
# builtins            logging             setuptools          zipfile
# bz2                 lxml                shellingham         zipimport
# cProfile            lz4                 shelve              zipp
# cachetools          lzma                shiboken6           zlib
# calendar            mailbox             shiboken6_generator zmq
# certifi             markdown            shlex               zoneinfo
# cffi                markdown_it         shutil              zope
# chardet             markupsafe          signal              zstandard
# charset_normalizer  marshal             sipbuild
# click               math                site
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %% [markdown]
# Alternatively, the `dir()` function is a built-in function that can be used to **list all the function names (or variable names) in a module**:
#
# `dir(module_name)`

# %%
# Import math module 
import math 

# Use the sqrt function in the math module
x = math.sqrt(81)
print('The square root of 81 is equal to {}'.format(x))

# List all functions in math module 
list_all= dir(math)
print('Functions in the math module: {}'.format(list_all))
# Out:
# The square root of 81 is equal to 9.0
# Functions in the math module: ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %% [markdown]
# ## Summary
#
# In this train, we learned how to create, import, and use modules. We also explored the use of built-in modules in Python and how to determine what functions are present within modules.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:140px";/>
# </div>
